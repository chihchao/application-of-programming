# %% [markdown]
# <a href="https://colab.research.google.com/github/chihchao/application-of-programming/blob/main/machine_learning_numerical_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 下載資料集並解壓縮
# !gdown '1xqOapGi_kPIue0C5r4zDS1fe57tWo-2P' --output ML.zip
# !unzip ML.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1xqOapGi_kPIue0C5r4zDS1fe57tWo-2P
# From (redirected): https://drive.google.com/uc?id=1xqOapGi_kPIue0C5r4zDS1fe57tWo-2P&confirm=t&uuid=12142f1a-c9bf-4053-9b0c-48b7c8ca7b2f
# To: /content/ML.zip
# 100% 44.6M/44.6M [00:01<00:00, 33.7MB/s]
# Archive:  ML.zip
#   inflating: housePrice.csv
#   inflating: mnist500.zip
#   inflating: mnist500_png.zip
#   inflating: toutiao_cat_data.txt
#   inflating: иTиоиолм╕ъо╞└╔.csv
#   inflating: л╚дс┴p╡╕кмкp╕ъо╞└╔.csv
#   inflating: breastCancer.csv
#   inflating: customer.csv

# %%
# 更改亂碼檔名
# !mv иTиоиолм╕ъо╞└╔.csv 汽車車型資料檔.csv
# !mv л╚дс┴p╡╕кмкp╕ъо╞└╔.csv 客戶聯絡狀況資料檔.csv

# %%
import pandas as pd

df = pd.read_csv('/content/汽車車型資料檔.csv')

df

# %% [markdown]
# 取得汽車車型資料

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-car_models.csv'
df = pd.read_csv(url)
df.head()
# Out:
#              名稱  哩/加侖  氣缸  排氣量     馬力    重量  加速時間  年份
# 0  Honda FozElU  47.6   4  345   66.0  3844  24.8  64
# 1  Lexus ZCKlVx  36.9   2  304   92.0  4733  25.5  93
# 2  Lexus pBOMcW  13.2  10  193  103.0  3496  29.6  71
# 3   Audi uFi6qm  58.5  10  148   50.0  4884  16.1  84
# 4    BMW YLHFKB  30.6   6  294  146.0  2387  24.6  67

# %%
df_std = df.iloc[:,1:8]
df_std
# Out:
#      哩/加侖  氣缸  排氣量     馬力    重量  加速時間   年份
# 0    47.6   4  345   66.0  3844  24.8   64
# 1    36.9   2  304   92.0  4733  25.5   93
# 2    13.2  10  193  103.0  3496  29.6   71
# 3    58.5  10  148   50.0  4884  16.1   84
# 4    30.6   6  294  146.0  2387  24.6   67
# ..    ...  ..  ...    ...   ...   ...  ...
# 375  38.4   4  304   90.0  3734  12.3   61
# 376  20.6   6  244   52.0  2941  25.8  106
# 377  58.3   4  266   76.0  3999  14.4  106
# 378  32.7   8  124  100.0  3005  24.4   89
# 379  24.3   6   76   94.0  3488  28.5   66
#
# [380 rows x 7 columns]

# %% [markdown]
# ## Z 分數標準化

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
arr = std.fit_transform(df_std)
arr
# Out:
# array([[ 0.8695159 , -0.60142067,  1.25298525, ...,  0.40281231,
#          0.81557814, -1.45824115],
#        [ 0.10715436, -1.30679059,  0.8350642 , ...,  1.43674579,
#          0.94113884,  0.40190672],
#        [-1.58144083,  1.51468909, -0.2963806 , ..., -0.00192206,
#          1.67656583, -1.00923994],
#        ...,
#        [ 1.63187744, -0.60142067,  0.44772274, ...,  0.58308193,
#         -1.04989518,  1.23576611],
#        [-0.19209036,  0.80931917, -0.99971114, ..., -0.57296969,
#          0.74382917,  0.1453346 ],
#        [-0.79057979,  0.10394925, -1.48898457, ..., -0.0112263 ,
#          1.47925615, -1.32995509]])

# %% [markdown]
# ## 最大最小值正規化

# %%
from sklearn.preprocessing import MinMaxScaler
std = MinMaxScaler()
arr = std.fit_transform(df_std)
arr
# Out:
# array([[0.75301205, 0.25      , 0.83823529, ..., 0.61378849, 0.74242424,
#         0.07843137],
#        [0.53815261, 0.        , 0.71764706, ..., 0.91131191, 0.77777778,
#         0.64705882],
#        [0.062249  , 1.        , 0.39117647, ..., 0.49732262, 0.98484848,
#         0.21568627],
#        ...,
#        [0.96787149, 0.25      , 0.60588235, ..., 0.66566265, 0.21717172,
#         0.90196078],
#        [0.45381526, 0.75      , 0.18823529, ..., 0.33299866, 0.72222222,
#         0.56862745],
#        [0.28514056, 0.5       , 0.04705882, ..., 0.49464525, 0.92929293,
#         0.11764706]])
